# %% [markdown]
# Name-Prateek
#
# Roll no-320
#
# Statistical Mechanics lab
#
# Experiment-1

# %% [markdown]
# # $\mathrm{I.}$ Planck Law , Wein's Law and Rayleigh Jeans Law

# %% [markdown]
# ### 1. Plot Planck’s law for blackbody at temperature a) 300K b) 400K c) 500K
#
#   <span style="font-size: 16px;">Planck's Law is given by the formula:</span>
#
#
# $$\displaystyle
# \mu(\lambda) = \frac{{8 \pi h c}}{{\lambda^5 \left(e^{\frac{{hc}}{{\lambda k T}}} - 1\right)}}
# $$
#
# Where:
# - $\mu(\lambda)$ is the spectral radiance,In the context of Planck's law, $\mu(\lambda)$ provides the radiant flux per unit wavelength interval, which indicates how much radiant energy is emitted per unit time per unit wavelength range at a given temperature.In other words $\mu(\lambda)$ is radiant flux per unit wavelength. Radiance is the radiant flux emitted, reflected, transmitted or received by a given surface,
# - $\lambda$ is the wavelength of light,
# - $h$ is Planck's constant,
# - $c$ is the speed of light in vacuum,
# - $k$ is the Boltzmann constant, and
# - $T$ is the temperature.

# %%
import matplotlib.pyplot as plt
import numpy as np
T=[300,400,500]
hc=1240
k=8.61*(10**(-5))
np.seterr(over='ignore') # to remove error message 
x=np.linspace(0.0001,50000,100000)
for t in T:
 y=(8*np.pi*hc)/((x**5) * (np.exp(hc/(x*k*t))-1))
 plt.plot(x,y)
 plt.ylabel("$\mu(\lambda)$", fontsize=15)  # Spectral radiance
 plt.xlabel("$\lambda$ (nm)", fontsize=15)  # Wavelength
 plt.grid(True)
 plt.legend(['300 K','400 K','500 K'])
# Out:
# <img src="data:image/png;base64,..." width="640.1154119267358">

# %% [markdown]
# ### 2.1 Verify Wein’s displacement law for all three temperatures
# $ \displaystyle \lambda_{max}T=a$
#
# where $a=2.898\times10^{-3}$m.K

# %%
T=[300,400,500]
lambda_max=[9668.59,7251.5,5801.05]
for i in range(len(T)):
    print(f'lambda_max{i+1}*T{i+1} is {T[i]*lambda_max[i]*1e-9}')
# Out:
# lambda_max1*T1 is 0.002900577
# lambda_max2*T2 is 0.0029006
# lambda_max3*T3 is 0.002900525

# %% [markdown]
# ### 2.2 Verify Stephan's law for all three temperatures
# Stefan's Law, also known as the Stefan-Boltzmann Law, states that the total energy radiated per unit surface area of a black body per unit time (\(P\)) is directly proportional to the fourth power of the black body's temperature $T$ :
#
# $$\displaystyle u = \sigma T^4 $$
#
# Where:
# - $P$ is the total power radiated per unit area (in watts per square meter),
# - $T$ is the absolute temperature of the black body (in kelvin), and
# - $\sigma$ is the Stefan-Boltzmann constant, approximately equal to $5.67 \times 10^{-8}$ watt per square meter per kelvin to the fourth $(\text{W m}^{-2} \text{K}^{-4}$).

# %%
from scipy.integrate import quad

# Define constants
hc = 1240
k = 8.61e-5
t1=300
t2=400
t3=500

def f(x,t):
    return (8 * np.pi * hc) / (x**5 * (np.exp(hc / (x * k * t)) - 1))

# Integrate the function from 0 to 200
u1,err = quad(f, 0,50000,t1)
u2,err=quad(f,0,50000,t2)
u3,err=quad(f,0,50000,t3)

print(f'u1/u2 ={u1/u2} and  t1^4/t2^4  is {(t1**4)/(t2**4)}')
print(f'u2/u3 ={u2/u3} and  t2^4/t3^4  is {(t2**4)/(t3**4)}')
print(f'u1/u3 ={u1/u3} and  t1^4/t3^4  is {(t1**4)/(t3**4)}')
# Out:
# u1/u2 =0.31105892791083967 and  t1^4/t2^4  is 0.31640625
# u2/u3 =0.4068577981513973 and  t2^4/t3^4  is 0.4096
# u1/u3 =0.12655675050513843 and  t1^4/t3^4  is 0.1296

# %% [markdown]
# ### 3. For a blackbody plot a) Plank's law b) Wein's law c) Rayleigh-Jeans law
# The Wien's distribution law describes the spectral radiance of blackbody radiation as a function of wavelength at a given temperature \( T \). It is given by the formula:
# - Plank's law
# $$\displaystyle
# \mu(\lambda) = \frac{{8 \pi h c}}{{\lambda^5 \left(e^{\frac{{hc}}{{\lambda k T}}} - 1\right)}}
# $$
# - Wein's law
# $$ \displaystyle
# \mu(\lambda) = \frac{{8\pi hc}}{{\lambda^5}} \cdot e^{\left(-\frac{{hc}}{{\lambda kT}}\right)}
# $$
# - Rayleigh-Jeans law
# $$ \displaystyle
# \mu(\lambda) = \frac{{8\pi kT}}{{\lambda^4}}
# $$

# %%
t=300
hc=1240
k=8.61*(10**(-5))

x=np.linspace(0.0001,50000,1000)
x1=np.linspace(20000,50000,1000)

y=(8*np.pi*hc)/((x**5)  * (np.exp(hc/(x*k*t))-1))
y1=(8*np.pi*k*t)/(x1**4)
y3=(8*np.pi*hc*np.exp(-hc/(x*k*t)))/((x**5))

plt.plot(x,y)
plt.plot(x1,y1)
plt.plot(x,y3,'--')
plt.ylabel("$\mu(\lambda)$", fontsize=15)  # spectral radiance
plt.xlabel("$\lambda$ (nm)", fontsize=15)  # Wavelength
plt.legend(["Planks law","Rayleigh-Jeans","Wien's law"])
plt.grid(True)
# Out:
# <img src="data:image/png;base64,..." width="640.1154119267358">

# %% [markdown]
# ## $\mathrm{II.}$ Sun as a Blackbody (T=5800K)

# %% [markdown]
# ### 1. Plot Plank's law for Sun (T=5800 K)
# <span style="font-size: 16px;">Planck's Law is given by the formula:</span>
# $$\displaystyle
# \mu(\lambda) = \frac{{8 \pi h c}}{{\lambda^5 \left(e^{\frac{{hc}}{{\lambda k T}}} - 1\right)}}
# $$
#
# Where:
# - $\mu(\lambda)$ is the spectral radiance,In the context of Planck's law, $\mu(\lambda)$ provides the radiant flux per unit wavelength interval, which indicates how much radiant energy is emitted per unit time per unit wavelength range at a given temperature.In other words $\mu(\lambda)$ is radiant flux per unit wavelength. Radiance is the radiant flux emitted, reflected, transmitted or received by a given surface.
# - $\lambda$ is the wavelength of light,
# - $h$ is Planck's constant,
# - $c$ is the speed of light in vacuum,
# - $k$ is the Boltzmann constant, and
# - $T$ is the temperature.

# %%
import matplotlib.pyplot as plt
import numpy as np
t=5800
hc=1240
k=8.61*(10**(-5))
np.seterr(over='ignore')
x=np.linspace(0.0001,4000,100000)
y=(8*np.pi*hc)/((x**5) * (np.exp(hc/(x*k*t))-1))
plt.plot(x,y,'r')
plt.ylabel("$\mu(\lambda)$", fontsize=15)  # Spectral radiance
plt.xlabel("$\lambda$ (nm)", fontsize=15)  # Wavelength
plt.title("Plank's law for Sun")
plt.grid(True)
plt.legend(['5800 K'])
# Out:
# <img src="data:image/png;base64,..." width="640.1154119267358">

# %% [markdown]
# ### 2. Find out percentage of radiation lying in
# - Visible region $\displaystyle [400$nm-$700$nm]
# - UV region $\displaystyle [100$nm-$400$nm]

# %%
from scipy.integrate import quad

def f(x,t):
    return (8*np.pi*hc)/(x**5*(np.exp(hc/(x*k*t))-1))

# Integrate the function from intial to final range to get area
total_area,err=quad(f,0,6000,t)
UV,err=quad(f,100,400,t)
visible,err=quad(f,400,700,t)
print(f'Radiation in Visible region is {(visible/total_area)*100:.3f} % of total.')
print(f'Radiation in UV region is {(UV/total_area)*100:.3f} % of total.')
# Out:
# Radiation in Visible region is 36.857 % of total.
# Radiation in UV region is 12.394 % of total.

# %% [markdown]
# ### 3. Find maximum wavelength at which Planck’s function shows maxima.

# %%
y=f(x,t)
max_y_index=np.argmax(y)
# Retrieve the corresponding x-value
max_x=x[max_y_index]
print(f"The wavelength at which Plank's function shows maxima is {max_x} nm")
# Out:
# The wavelength at which Plank's function shows maxima is 500.1250887468874 nm

# %% [markdown]
# ### 4. Show that percentage of radiation lying below and above maxima is 25% and 75% respectively.

# %%
below_max,err=quad(f,0.001,max_x,t)
above_max,err=quad(f,max_x,50000,t)
print(f'Percentage of radiation below lambda_max is {(below_max/total_area)*100:.3f} % of total.')
print(f'Percentage of radiation above lambda_max is {(above_max/total_area)*100:.3f} % of total.')
# Out:
# Percentage of radiation below lambda_max is 25.088 % of total.
# Percentage of radiation above lambda_max is 75.207 % of total.
