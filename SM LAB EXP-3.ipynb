# %% [markdown]
# Name-Prateek
#
# Roll no-320
#
# Statistical Mechanics Lab
#
# Experiment-3

# %% [markdown]
# ### Solution-1

# %%
import numpy as np
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings("ignore")
T=[300,400,500]
k=8.61*10e-5
x=np.linspace(0,5,1000)
for t in T:
    f_mb=1/(np.exp(x/(k*t)))
    plt.plot(x,f_mb)
plt.grid(True)
plt.legend(['300 K','400 K','500 K'])
plt.ylabel('$f_{Mb}(x)$')
plt.xlabel('Energy (eV)')
plt.title('Maxwell-Boltzmann Distribution')
# Out:
# <img src="data:image/png;base64,..." width="640.1154119267358">
# Text(0.5, 1.0, 'Maxwell-Boltzmann Distribution')

# %% [markdown]
# ### Solution-2 a)

# %%
#%matplotlib notebook
T=[0,10,50,500]
mu=0.025
x=np.linspace(0,0.5,1000)
for t in T:
 f_fd=1/(np.exp((x-mu)/(k*t))+1)
 plt.plot(x,f_fd)
plt.grid(True)
plt.legend(['0 K','10 K','50 K','500 K '])
plt.ylabel('$f_{Fd}(x)$')
plt.xlabel('Energy (eV)')
plt.title('Fermi-Dirac Distribution')
# Out:
# <img src="data:image/png;base64,..." width="640.1154119267358">
# Text(0.5, 1.0, 'Fermi-Dirac Distribution')

# %% [markdown]
# ### Solution-2 b)

# %%
T=[0,300,500,12000]
mu=7.0
x=np.linspace(0,15,1000)
for t in T:
 f_fd=1/(np.exp((x-mu)/(k*t))+1)
 plt.plot(x,f_fd)
plt.grid(True)
plt.legend(['0 K','300 K','500 K','12000 K '])
plt.ylabel('$f_{Fd}(x)$')
plt.xlabel('Energy (eV)')
plt.title('Fermi-Dirac Distribution')
# Out:
# <img src="data:image/png;base64,..." width="640.1154119267358">
# Text(0.5, 1.0, 'Fermi-Dirac Distribution')

# %% [markdown]
# ### Solution-3 a)

# %%
T=[300,400,500]
mu=-0.15
x=np.linspace(-0.14,0.15,1000) # don't take x=-0.15
for t in T:
 f_Be=1/(np.exp((x-mu)/(k*t))-1)
 plt.plot(x,f_Be)
plt.grid(True)
plt.legend(['300 K','400 K','500 K '])
plt.ylabel('$f_{Be}(x)$')
plt.xlabel('Energy (eV)')
plt.title('Bose-Einstein Distribution')
# Out:
# <img src="data:image/png;base64,..." width="640.1154119267358">
# Text(0.5, 1.0, 'Bose-Einstein Distribution')

# %% [markdown]
# ### Solution-3 b)

# %%
# %matplotlib notebook
t=300
Mu=[-0.15,-0.16,-0.18]
x=np.linspace(-0.14,0.15,1000)
for mu in Mu:
 f_Be=1/(np.exp((x-mu)/(k*t))-1)
 plt.plot(x,f_Be)
plt.grid(True)
plt.legend(['u=-0.15','u=-0.16','u=-0.18 '])
plt.ylabel('$f_{Be}(x)$')
plt.xlabel('Energy (eV)')
plt.title('Bose-Einstein Distribution')
# Out:
# <img src="data:image/png;base64,..." width="640.1154119267358">
# Text(0.5, 1.0, 'Bose-Einstein Distribution')
